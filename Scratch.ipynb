# %%
from gettsim import plot
interface = plot.dag.interface(
    include_fail_and_warn_nodes=False,
    show_node_description=True,
    output_path="interface.html",
)

# %%
from gettsim.plot import dag
from gettsim import Labels

fig = dag.tt(
    policy_date_str="2025-01-01",
    primary_nodes={"sozialversicherung__rente__jahr_renteneintritt"},
    # labels=Labels(input_columns={"orc_hunting_bounty__amount_without_topup"}),
    selection_type="descendants",
    include_params=False,
    #title="Ancestors Plot: orc_hunting_bounty__amount"
    output_path="dag.html",
)
